# %% [markdown]
# This notebook contains Named Entity Recognition evaluation for the baseline and final models to produce the results reported.

# %% [markdown]
# Install required dependencies

# %%
# !pip install datasets -q
# !pip install transformers -q
# !pip install git+https://github.com/huggingface/evaluate.git
# !pip install huggingface_hub -q
# !pip install seqeval
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 4.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 46.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 88.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Final mode evaluation for metrics

# %%
from evaluate import evaluator
from datasets import load_dataset
from transformers import pipeline
task_evaluator = evaluator("token-classification")
data = load_dataset("conllpp", split="test")
pipe = pipeline("token-classification", model="sentientconch/retrained_ner", use_auth_token='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')
results = task_evaluator.compute(
    model_or_pipeline=pipe,
    data=data,
    metric="seqeval",
    input_column='tokens',
    label_column='ner_tags'
)
# Out:
# WARNING:datasets.builder:Found cached dataset conllpp (/root/.cache/huggingface/datasets/conllpp/conllpp/1.0.0/04f15f257dff3fe0fb36e049b73d51ecdf382698682f5e590b7fb13898206ba2)
# Map:   0%|          | 0/3453 [00:00<?, ? examples/s]

# %%
results
# Out:
# {'LOC': {'precision': 0.9264967397747481,
#   'recall': 0.9495747266099636,
#   'f1': 0.9378937893789379,
#   'number': 1646},
#  'MISC': {'precision': 0.8193103448275862,
#   'recall': 0.8215767634854771,
#   'f1': 0.8204419889502763,
#   'number': 723},
#  'ORG': {'precision': 0.8983861326957562,
#   'recall': 0.8763848396501458,
#   'f1': 0.8872491145218419,
#   'number': 1715},
#  'PER': {'precision': 0.9800249687890137,
#   'recall': 0.9703337453646477,
#   'f1': 0.9751552795031055,
#   'number': 1618},
#  'overall_precision': 0.9196412871461227,
#  'overall_recall': 0.9172220273588214,
#  'overall_f1': 0.9184300640969356,
#  'overall_accuracy': 0.9830300419941854,
#  'total_time_in_seconds': 431.17096705899985,
#  'samples_per_second': 8.008424183921234,
#  'latency_in_seconds': 0.12486851058760494}

# %% [markdown]
# Baseline model evaluation for metrics

# %%
from evaluate import evaluator
from datasets import load_dataset
from transformers import pipeline
task_evaluator = evaluator("token-classification")
data = load_dataset("wikiann", "en", split="validation")
pipe = pipeline("token-classification", model="sentientconch/final_ner", use_auth_token='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')
results = task_evaluator.compute(
    model_or_pipeline=pipe,
    data=data,
    metric="seqeval",
    input_column='tokens',
    label_column='ner_tags'
)
# Out:
# WARNING:datasets.builder:Found cached dataset wikiann (/root/.cache/huggingface/datasets/wikiann/en/1.1.0/4bfd4fe4468ab78bb6e096968f61fab7a888f44f9d3371c2f3fea7e74a5a354e)
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]

# %%
results
# Out:
# {'LOC': {'precision': 0.8631386861313869,
#   'recall': 0.8806371534960695,
#   'f1': 0.8718001228752817,
#   'number': 4834},
#  'ORG': {'precision': 0.7760593220338983,
#   'recall': 0.7831943553559975,
#   'f1': 0.7796105139938277,
#   'number': 4677},
#  'PER': {'precision': 0.8987612131567706,
#   'recall': 0.9078748651564186,
#   'f1': 0.9032950520553826,
#   'number': 4635},
#  'overall_precision': 0.8461001813869122,
#  'overall_recall': 0.8573448324614732,
#  'overall_f1': 0.851685393258427,
#  'overall_accuracy': 0.9358547730207609,
#  'total_time_in_seconds': 1136.2239041089997,
#  'samples_per_second': 8.80108221965438,
#  'latency_in_seconds': 0.11362239041089997}
